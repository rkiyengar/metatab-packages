# %%
import metatab as mt
import pandas as pd

df = pd.read_csv('https://data.lacounty.gov/api/views/8rdv-6nb6/rows.csv?accessType=DOWNLOAD')

# %%
df.iloc[:5].T
# Out:
#                                                                      0  \
# Year                                                              2013
# Employee Last Name                                         ABDEL-FATAH
# Employee First Name                                            IBRAHIM
# Middle Initial                                                       M
# Position Title           AGRICULTURAL/WEIGHTS & MEASURES INSPECTOR III
# Department                                   Agric Comm/Wts & Measures
# Base Earnings                                                $68167.65
# Overtime Earnings                                            $12323.27
# Other Earnings                                                $2367.37
# Leave Time Payouts                                            $1560.56
#  Total Earnings                                              $84418.85
# Medical, Dental, Vision                                      $16595.76
# ...
