# %%
from metatab import open_package
doc = open_package("http://library.metatab.org/cde.ca.gov-fitnessgram-1999e-ca-2")
#doc = open_package("../cde.ca.gov-fitnessgram-1999e-ca-2")
doc
# Out:
# <h1>California Physical Fitness Test  Research Data</h1>
# <p>cde.ca.gov-fitnessgram-1999e-ca-2</p>
# <p>These research files contain results from the Physical Fitness Test (PFT) program. Each file contains the same information presented in the Reports section of this site and is provided to allow for more complex analyses and customized reporting of the data. The data files, including file layout, entities, and subgroup files, are comma-delimited text files provided in a zip format.</p>
# <table>
# <tr><td>Homepage</td><td><a href="http://www.cde.ca.gov/ta/tg/pf/" target="_blank" >Physical Fitness Testing (PFT)</a></td></td><td>Home page for the PFT program</td></tr>
# <tr><td>Downloadpage</td><td><a href="http://www.cde.ca.gov/ta/tg/pf/pftresearch.asp" target="_blank" >PFT Statewide Research Files</a></td></td><td>Download page with links to research file archives</td></tr>
# ...

# %%
doc.resource('physfit10')
# Out:
# <Term: metadata.csv 69:1 root.datafile data/physfit10.csv ['physfit10', '3623041', '', '2010', 'physfit_1999e2010', '2010 PFT Fitness Results']>

# %%
##
## Note! These files are very large, so creating a data frame takes a long time. 
##
df = doc.resource('physfit10').dataframe(limit=1000)
df.loc[:5].T
# Out:
#                           0               1               2               3  \
# level                     4               4               4               4
# subgrp                    0               0               0               0
# rpttype                   1               1               1               1
# line_num                  1               2               3               4
# ccode                     0               0               0               0
# dcode                     0               0               0               0
# charternum             0000            0000            0000            0000
# scode                     0               0               0               0
# cds_code     00000000000000  00000000000000  00000000000000  00000000000000
# gr05_stu             447863          447863          447863          447863
# gr5pctin               65.4            68.5            79.4            88.2
# ...
